# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
with open(r'C:\Users\verya\.secret\yelp_api.json') as f:   #use your path here!
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
location = 'Sunnyvale, CA'
term = 'sushi'

# %%
location.split(',')[0]
# Out:
# 'Sunnyvale'

# %%
# set our API call parameters 
LOCATION = 'Sunnyvale, CA'
TERM = 'sushi'

# %%
## Choose folder to save files
FOLDER = 'G:\Github Desktop Reps\Coding Dojo\Yelp-API\Data'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"
JSON_FILE
# Out:
# 'G:\\Github Desktop Reps\\Coding Dojo\\Yelp-API\\DataSunnyvale-sushi.json'

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder) > 0: 
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
## If it exists, inform user
else:
    print (f"[i] {JSON_FILE} already exists.")
# Out:
# [i] G:\Github Desktop Reps\Coding Dojo\Yelp-API\DataSunnyvale-sushi.json already exists.

# %%
results = yelp_api.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 368

# %%
results['region']
# Out:
# {'center': {'longitude': -122.02445983886719, 'latitude': 37.373965811146164}}

# %%
results['businesses']
# Out:
# [{'id': 'P9G-frt9vxikF0TPlL_xnQ',
#   'alias': 'tanto-japanese-restaurant-sunnyvale-2',
#   'name': 'Tanto Japanese Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/U9dzcbdLT3Oi--uY4N1Gnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tanto-japanese-restaurant-sunnyvale-2?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 1540,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'izakaya', 'title': 'Izakaya'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.3525904613423,
#    'longitude': -122.003645896912},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1063 E El Camino Real',
#    'address2': '',
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94087',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1063 E El Camino Real', 'Sunnyvale, CA 94087']},
#   'phone': '+14082447311',
#   'display_phone': '(408) 244-7311',
#   'distance': 3005.503957996992},
#  {'id': '0IJgsg9ieOwSUtBOGF43XA',
#   'alias': 'sakebomb-sushi-and-grill-sunnyvale-2',
#   'name': 'Sakebomb Sushi & Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qsVFSSaCZb7tmOOLukRaOw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sakebomb-sushi-and-grill-sunnyvale-2?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 333,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'izakaya', 'title': 'Izakaya'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.358093, 'longitude': -122.019296},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '759 E El Camino Real',
#    'address2': None,
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94087',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['759 E El Camino Real', 'Sunnyvale, CA 94087']},
#   'phone': '+14082124123',
#   'display_phone': '(408) 212-4123',
#   'distance': 1823.0172536507923},
#  {'id': 'VbPU2itFPckFKv5bizLMAQ',
#   'alias': 'fugetsu-sunnyvale-sunnyvale-2',
#   'name': 'Fugetsu - Sunnyvale',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C7fF6oSDHjN8_FIqYZHyxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fugetsu-sunnyvale-sunnyvale-2?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 727,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.376484715741775, 'longitude': -122.0312941},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '190 S Frances St',
#    'address2': None,
#    'address3': 'Rokko Japanese Restaurant',
#    'city': 'Sunnyvale',
#    'zip_code': '94086',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['190 S Frances St',
#     'Rokko Japanese Restaurant',
#     'Sunnyvale, CA 94086']},
#   'phone': '+14087738225',
#   'display_phone': '(408) 773-8225',
#   'distance': 665.6936886074325},
#  {'id': 'j2rJ3W5c_CZ2tQh2QJ4oUA',
#   'alias': 'sushi-tomi-mountain-view-2',
#   'name': 'Sushi Tomi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WyWB3fyRUqvfd4tV187yOQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-tomi-mountain-view-2?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 2496,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.3915303378286, 'longitude': -122.07806645178},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '635 W Dana St',
#    'address2': '',
#    'address3': '',
#    'city': 'Mountain View',
#    'zip_code': '94040',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['635 W Dana St', 'Mountain View, CA 94040']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 5123.299043428106},
#  {'id': '4eTRqnAqFd2SDB0AvrMtQw',
#   'alias': 'amami-shima-sushi-cupertino',
#   'name': 'Amami Shima Sushi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pxcpMMFRhd9xqlo3s5aP4A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amami-shima-sushi-cupertino?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 1101,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.32265, 'longitude': -122.00596},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '19068 Stevens Creek Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Cupertino',
#    'zip_code': '95014',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['19068 Stevens Creek Blvd', 'Cupertino, CA 95014']},
#   'phone': '+14089968815',
#   'display_phone': '(408) 996-8815',
#   'distance': 5944.94654166972},
#  {'id': 'hL8RzQIgXKh8SQ2P0KYx5Q',
#   'alias': 'pacific-catch-sunnyvale',
#   'name': 'Pacific Catch',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/59W6VWAp5nuxQt5-pQ5XsA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pacific-catch-sunnyvale?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 110,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.374423, 'longitude': -122.033312},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '300 W McKinley Ave',
#    'address2': 'Ste F-170',
#    'address3': None,
#    'city': 'Sunnyvale',
#    'zip_code': '94086',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['300 W McKinley Ave',
#     'Ste F-170',
#     'Sunnyvale, CA 94086']},
#   'phone': '+16696003858',
#   'display_phone': '(669) 600-3858',
#   'distance': 782.6531385304245},
#  {'id': '1ybJc4pL9EUt5TveiKPX4w',
#   'alias': 'katana-sushi-and-sake-sunnyvale',
#   'name': 'Katana Sushi & Sake',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cw5rWYz0Q55NKhshnQGqKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/katana-sushi-and-sake-sunnyvale?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 596,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3656743273312,
#    'longitude': -122.027934249622},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '411 E El Camino Real',
#    'address2': None,
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94087',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['411 E El Camino Real', 'Sunnyvale, CA 94087']},
#   'phone': '+14087463000',
#   'display_phone': '(408) 746-3000',
#   'distance': 971.7504424963606},
#  {'id': 'LP-jPvjRPe8EYdPFxz4LvQ',
#   'alias': 'rantei-japanese-cuisine-santa-clara',
#   'name': 'Rantei Japanese Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EC7xvgMkhxmDCSSk4oXiFw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rantei-japanese-cuisine-santa-clara?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 772,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.34898, 'longitude': -121.94779},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '1271 Franklin Mall',
#    'address2': None,
#    'address3': '',
#    'city': 'Santa Clara',
#    'zip_code': '95050',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1271 Franklin Mall', 'Santa Clara, CA 95050']},
#   'phone': '+14083525683',
#   'display_phone': '(408) 352-5683',
#   'distance': 7320.768423598632},
#  {'id': 'xIsXoKcWJ60Pn0zh_cIcYQ',
#   'alias': 'rokko-fine-japanese-cuisine-sunnyvale-2',
#   'name': 'Rokko Fine Japanese Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XJH54CaIYYSp15Mh5sEv2w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rokko-fine-japanese-cuisine-sunnyvale-2?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 404,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3764207004337,
#    'longitude': -122.031285805202},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '190 S Frances St',
#    'address2': None,
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94086',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['190 S Frances St', 'Sunnyvale, CA 94086']},
#   'phone': '+14087738225',
#   'display_phone': '(408) 773-8225',
#   'distance': 662.0625993221885},
#  {'id': 'kzqtQMANL6lmBJh6hooyZw',
#   'alias': 'happy-sushi-santa-clara-2',
#   'name': 'Happy Sushi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qcEwNajgj2BDS9KpwkW_UQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/happy-sushi-santa-clara-2?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 601,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.35195, 'longitude': -121.9851},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3216 El Camino Real',
#    'address2': 'Ste 5',
#    'address3': '',
#    'city': 'Santa Clara',
#    'zip_code': '95051',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3216 El Camino Real',
#     'Ste 5',
#     'Santa Clara, CA 95051']},
#   'phone': '+14086387606',
#   'display_phone': '(408) 638-7606',
#   'distance': 4258.83480308307},
#  {'id': 'e4uhBPj7zDYecDTmuejiSA',
#   'alias': 'kura-revolving-sushi-bar-cupertino-4',
#   'name': 'Kura Revolving Sushi Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CHUvzB4GxuW3nRSA3a1bxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kura-revolving-sushi-bar-cupertino-4?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 2559,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'conveyorsushi', 'title': 'Conveyor Belt Sushi'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3253738, 'longitude': -122.01189},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '19600 Vallco Pkwy',
#    'address2': 'Ste 160',
#    'address3': '',
#    'city': 'Cupertino',
#    'zip_code': '95014',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['19600 Vallco Pkwy', 'Ste 160', 'Cupertino, CA 95014']},
#   'phone': '+14088610155',
#   'display_phone': '(408) 861-0155',
#   'distance': 5516.238381853229},
#  {'id': 'h_pgKdsPzhmUKJZnxULBzw',
#   'alias': 'katsu-mountain-view',
#   'name': 'Katsu',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4tIiA2TTUtW7yuSGv4V0pw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/katsu-mountain-view?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 29,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.39400300492779,
#    'longitude': -122.0796424374888},
#   'transactions': [],
#   'location': {'address1': '859 Villa St',
#    'address2': '',
#    'address3': None,
#    'city': 'Mountain View',
#    'zip_code': '94041',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['859 Villa St', 'Mountain View, CA 94041']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 5360.545222633758},
#  {'id': 'Dh_tpGG73WYiHVU4dYknCA',
#   'alias': 'sawa-sushi-sunnyvale',
#   'name': 'Sawa Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YEyoInFYr9MughuGFMLQJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sawa-sushi-sunnyvale?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 272,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.35163, 'longitude': -122.00432},
#   'transactions': ['pickup'],
#   'price': '$$$$',
#   'location': {'address1': '1042 E El Camino Real',
#    'address2': '',
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94087',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1042 E El Camino Real', 'Sunnyvale, CA 94087']},
#   'phone': '+14082417292',
#   'display_phone': '(408) 241-7292',
#   'distance': 3055.933606859625},
#  {'id': 'OKV3pQfQcpy_pPU1SrBOWg',
#   'alias': 'hanamaru-sunnyvale',
#   'name': 'Hanamaru',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tZrIhOZ95XWPKiYqCxqpLQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hanamaru-sunnyvale?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 704,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.37257, 'longitude': -122.05773},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '675 S Bernardo Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94087',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['675 S Bernardo Ave', 'Sunnyvale, CA 94087']},
#   'phone': '+14085245353',
#   'display_phone': '(408) 524-5353',
#   'distance': 2924.7385067917753},
#  {'id': 'RisyzF442yNXb3qwMDuCug',
#   'alias': 'bay-sushi-sunnyvale-2',
#   'name': 'Bay Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/krd_QN4EsS5aFgXG8M7VDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bay-sushi-sunnyvale-2?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 214,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.3394, 'longitude': -122.0415349},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1647 Hollenbeck Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94087',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1647 Hollenbeck Ave', 'Sunnyvale, CA 94087']},
#   'phone': '+14087351777',
#   'display_phone': '(408) 735-1777',
#   'distance': 4134.754962989693},
#  {'id': 'QxjnhtNCCGb-DrjJNqPBlw',
#   'alias': 'joy-sushi-mountain-view',
#   'name': 'Joy Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0KqlHlGwjjSyfmvfEOW9_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joy-sushi-mountain-view?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 521,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.39701, 'longitude': -122.06141},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '225 E Middlefield Rd',
#    'address2': 'Ste 1B',
#    'address3': '',
#    'city': 'Mountain View',
#    'zip_code': '94043',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['225 E Middlefield Rd',
#     'Ste 1B',
#     'Mountain View, CA 94043']},
#   'phone': '+16509039403',
#   'display_phone': '(650) 903-9403',
#   'distance': 4136.558960955245},
#  {'id': 'umX6_PPMuO1SlVPlyoy8FA',
#   'alias': 'seto-restaurant-sunnyvale',
#   'name': 'Seto Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/61Tmvtpa1Qzu6IqMGXfFzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/seto-restaurant-sunnyvale?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 400,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3885018150518, 'longitude': -122.02588316745},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '511 Borregas Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Sunnyvale',
#    'zip_code': '94085',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['511 Borregas Ave', 'Sunnyvale, CA 94085']},
#   'phone': '+14087358280',
#   'display_phone': '(408) 735-8280',
#   'distance': 1621.2132226708982},
#  {'id': 'zCcGMkDIszN3-ACUxJHhgQ',
#   'alias': 'sushi-jin-mountain-view',
#   'name': 'Sushi Jin',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nTBmEItuH_W7yN6x7Eqi_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-jin-mountain-view?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 203,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.411209, 'longitude': -122.094568},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '580 N Rengstorff Ave',
#    'address2': 'Ste J',
#    'address3': None,
#    'city': 'Mountain View',
#    'zip_code': '94043',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['580 N Rengstorff Ave',
#     'Ste J',
#     'Mountain View, CA 94043']},
#   'phone': '+16503865885',
#   'display_phone': '(650) 386-5885',
#   'distance': 7339.576956928149},
#  {'id': 'd21yLIv0j4Cc2WVNsQAmZw',
#   'alias': 'gochi-cupertino-cupertino',
#   'name': 'Gochi - Cupertino',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F8sJpyaQ2uyQC77GD-PUYA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gochi-cupertino-cupertino?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 2173,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.3368621985872,
#    'longitude': -122.022732496261},
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '19980 E Homestead Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cupertino',
#    'zip_code': '95014',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['19980 E Homestead Rd', 'Cupertino, CA 95014']},
#   'phone': '+14087250542',
#   'display_phone': '(408) 725-0542',
#   'distance': 4128.552853703201},
#  {'id': '0WelkDuiaSkUK-PZ9gVodw',
#   'alias': 'omee-j-fusion-sushi-bar-and-grill-santa-clara-3',
#   'name': 'Omee.J Fusion Sushi Bar & Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7zKpSVkt9Zxl8QieSqtFdw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/omee-j-fusion-sushi-bar-and-grill-santa-clara-3?adjust_creative=phHf8rY44sgp0qvBAX7I9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=phHf8rY44sgp0qvBAX7I9w',
#   'review_count': 1090,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.3237438075576,
#    'longitude': -121.980671473249},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '4477 Stevens Creek Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Santa Clara',
#    'zip_code': '95051',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4477 Stevens Creek Blvd', 'Santa Clara, CA 95051']},
#   'phone': '+14082438282',
#   'display_phone': '(408) 243-8282',
#   'distance': 6794.69829351815}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                            alias  \
# 0   P9G-frt9vxikF0TPlL_xnQ            tanto-japanese-restaurant-sunnyvale-2
# 1   0IJgsg9ieOwSUtBOGF43XA             sakebomb-sushi-and-grill-sunnyvale-2
# 2   VbPU2itFPckFKv5bizLMAQ                    fugetsu-sunnyvale-sunnyvale-2
# 3   j2rJ3W5c_CZ2tQh2QJ4oUA                       sushi-tomi-mountain-view-2
# 4   4eTRqnAqFd2SDB0AvrMtQw                      amami-shima-sushi-cupertino
# 5   hL8RzQIgXKh8SQ2P0KYx5Q                          pacific-catch-sunnyvale
# 6   1ybJc4pL9EUt5TveiKPX4w                  katana-sushi-and-sake-sunnyvale
# 7   LP-jPvjRPe8EYdPFxz4LvQ              rantei-japanese-cuisine-santa-clara
# 8   xIsXoKcWJ60Pn0zh_cIcYQ          rokko-fine-japanese-cuisine-sunnyvale-2
# 9   kzqtQMANL6lmBJh6hooyZw                        happy-sushi-santa-clara-2
# 10  e4uhBPj7zDYecDTmuejiSA             kura-revolving-sushi-bar-cupertino-4
# 11  h_pgKdsPzhmUKJZnxULBzw                              katsu-mountain-view
# 12  Dh_tpGG73WYiHVU4dYknCA                             sawa-sushi-sunnyvale
# 13  OKV3pQfQcpy_pPU1SrBOWg                               hanamaru-sunnyvale
# 14  RisyzF442yNXb3qwMDuCug                            bay-sushi-sunnyvale-2
# 15  QxjnhtNCCGb-DrjJNqPBlw                          joy-sushi-mountain-view
# 16  umX6_PPMuO1SlVPlyoy8FA                        seto-restaurant-sunnyvale
# 17  zCcGMkDIszN3-ACUxJHhgQ                          sushi-jin-mountain-view
# 18  d21yLIv0j4Cc2WVNsQAmZw                        gochi-cupertino-cupertino
# 19  0WelkDuiaSkUK-PZ9gVodw  omee-j-fusion-sushi-bar-and-grill-santa-clara-3
#
#                                name  \
# 0         Tanto Japanese Restaurant
# 1            Sakebomb Sushi & Grill
# 2               Fugetsu - Sunnyvale
# 3                        Sushi Tomi
# 4                 Amami Shima Sushi
# 5                     Pacific Catch
# 6               Katana Sushi & Sake
# 7           Rantei Japanese Cuisine
# 8       Rokko Fine Japanese Cuisine
# 9                       Happy Sushi
# 10         Kura Revolving Sushi Bar
# 11                            Katsu
# 12                       Sawa Sushi
# 13                         Hanamaru
# 14                        Bay Sushi
# 15                        Joy Sushi
# 16                  Seto Restaurant
# 17                        Sushi Jin
# 18                Gochi - Cupertino
# 19  Omee.J Fusion Sushi Bar & Grill
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/U9dzcb...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/qsVFSS...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/C7fF6o...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/WyWB3f...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/pxcpMM...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/59W6VW...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/Cw5rWY...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/EC7xvg...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/XJH54C...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/qcEwNa...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/CHUvzB...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/4tIiA2...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/YEyoIn...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/tZrIhO...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/krd_QN...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/0KqlHl...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/61Tmvt...      False
# 17  https://s3-media4.fl.yelpcdn.com/bphoto/nTBmEI...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/F8sJpy...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/7zKpSV...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/tanto-japanese-restau...          1540
# 1   https://www.yelp.com/biz/sakebomb-sushi-and-gr...           333
# 2   https://www.yelp.com/biz/fugetsu-sunnyvale-sun...           727
# 3   https://www.yelp.com/biz/sushi-tomi-mountain-v...          2496
# 4   https://www.yelp.com/biz/amami-shima-sushi-cup...          1101
# 5   https://www.yelp.com/biz/pacific-catch-sunnyva...           110
# 6   https://www.yelp.com/biz/katana-sushi-and-sake...           596
# 7   https://www.yelp.com/biz/rantei-japanese-cuisi...           772
# 8   https://www.yelp.com/biz/rokko-fine-japanese-c...           404
# 9   https://www.yelp.com/biz/happy-sushi-santa-cla...           601
# 10  https://www.yelp.com/biz/kura-revolving-sushi-...          2559
# 11  https://www.yelp.com/biz/katsu-mountain-view?a...            29
# 12  https://www.yelp.com/biz/sawa-sushi-sunnyvale?...           272
# 13  https://www.yelp.com/biz/hanamaru-sunnyvale?ad...           704
# 14  https://www.yelp.com/biz/bay-sushi-sunnyvale-2...           214
# 15  https://www.yelp.com/biz/joy-sushi-mountain-vi...           521
# 16  https://www.yelp.com/biz/seto-restaurant-sunny...           400
# 17  https://www.yelp.com/biz/sushi-jin-mountain-vi...           203
# 18  https://www.yelp.com/biz/gochi-cupertino-cuper...          2173
# 19  https://www.yelp.com/biz/omee-j-fusion-sushi-b...          1090
#
#                                            categories  rating  \
# 0   [{'alias': 'tapasmallplates', 'title': 'Tapas/...     4.0
# 1   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 2   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 3   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 4   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 5   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 6   [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 7   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 8   [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 9   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 10  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 11  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 12  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 13  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 14  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 15  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 16  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 17  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 18  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 19        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.0
#
#                                           coordinates  \
# 0   {'latitude': 37.3525904613423, 'longitude': -1...
# 1   {'latitude': 37.358093, 'longitude': -122.019296}
# 2   {'latitude': 37.376484715741775, 'longitude': ...
# 3   {'latitude': 37.3915303378286, 'longitude': -1...
# 4     {'latitude': 37.32265, 'longitude': -122.00596}
# 5   {'latitude': 37.374423, 'longitude': -122.033312}
# 6   {'latitude': 37.3656743273312, 'longitude': -1...
# 7     {'latitude': 37.34898, 'longitude': -121.94779}
# 8   {'latitude': 37.3764207004337, 'longitude': -1...
# 9      {'latitude': 37.35195, 'longitude': -121.9851}
# 10  {'latitude': 37.3253738, 'longitude': -122.01189}
# 11  {'latitude': 37.39400300492779, 'longitude': -...
# 12    {'latitude': 37.35163, 'longitude': -122.00432}
# 13    {'latitude': 37.37257, 'longitude': -122.05773}
# 14   {'latitude': 37.3394, 'longitude': -122.0415349}
# 15    {'latitude': 37.39701, 'longitude': -122.06141}
# 16  {'latitude': 37.3885018150518, 'longitude': -1...
# 17  {'latitude': 37.411209, 'longitude': -122.094568}
# 18  {'latitude': 37.3368621985872, 'longitude': -1...
# 19  {'latitude': 37.3237438075576, 'longitude': -1...
#
#                                   transactions price  \
# 0                                   [delivery]    $$
# 1                                   [delivery]    $$
# 2                                     [pickup]    $$
# 3                                   [delivery]    $$
# 4                           [delivery, pickup]    $$
# 5                           [delivery, pickup]    $$
# 6                                   [delivery]    $$
# 7                           [delivery, pickup]   $$$
# 8                                   [delivery]    $$
# 9                           [delivery, pickup]    $$
# 10                          [delivery, pickup]    $$
# 11                                          []   NaN
# 12                                    [pickup]  $$$$
# 13                          [delivery, pickup]    $$
# 14                                  [delivery]    $$
# 15                          [delivery, pickup]    $$
# 16                          [delivery, pickup]    $$
# 17                                          []  $$$$
# 18  [delivery, pickup, restaurant_reservation]    $$
# 19                                  [delivery]   $$$
#
#                                              location         phone  \
# 0   {'address1': '1063 E El Camino Real', 'address...  +14082447311
# 1   {'address1': '759 E El Camino Real', 'address2...  +14082124123
# 2   {'address1': '190 S Frances St', 'address2': N...  +14087738225
# 3   {'address1': '635 W Dana St', 'address2': '', ...
# 4   {'address1': '19068 Stevens Creek Blvd', 'addr...  +14089968815
# 5   {'address1': '300 W McKinley Ave', 'address2':...  +16696003858
# 6   {'address1': '411 E El Camino Real', 'address2...  +14087463000
# 7   {'address1': '1271 Franklin Mall', 'address2':...  +14083525683
# 8   {'address1': '190 S Frances St', 'address2': N...  +14087738225
# 9   {'address1': '3216 El Camino Real', 'address2'...  +14086387606
# 10  {'address1': '19600 Vallco Pkwy', 'address2': ...  +14088610155
# 11  {'address1': '859 Villa St', 'address2': '', '...
# 12  {'address1': '1042 E El Camino Real', 'address...  +14082417292
# 13  {'address1': '675 S Bernardo Ave', 'address2':...  +14085245353
# 14  {'address1': '1647 Hollenbeck Ave', 'address2'...  +14087351777
# 15  {'address1': '225 E Middlefield Rd', 'address2...  +16509039403
# 16  {'address1': '511 Borregas Ave', 'address2': '...  +14087358280
# 17  {'address1': '580 N Rengstorff Ave', 'address2...  +16503865885
# 18  {'address1': '19980 E Homestead Rd', 'address2...  +14087250542
# 19  {'address1': '4477 Stevens Creek Blvd', 'addre...  +14082438282
#
#      display_phone     distance
# 0   (408) 244-7311  3005.503958
# 1   (408) 212-4123  1823.017254
# 2   (408) 773-8225   665.693689
# 3                   5123.299043
# 4   (408) 996-8815  5944.946542
# 5   (669) 600-3858   782.653139
# 6   (408) 746-3000   971.750442
# 7   (408) 352-5683  7320.768424
# 8   (408) 773-8225   662.062599
# 9   (408) 638-7606  4258.834803
# 10  (408) 861-0155  5516.238382
# 11                  5360.545223
# 12  (408) 241-7292  3055.933607
# 13  (408) 524-5353  2924.738507
# 14  (408) 735-1777  4134.754963
# 15  (650) 903-9403  4136.558961
# 16  (408) 735-8280  1621.213223
# 17  (650) 386-5885  7339.576957
# 18  (408) 725-0542  4128.552854
# 19  (408) 243-8282  6794.698294

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
(results['total'])/ results_per_page
# Out:
# 18.4

# %%
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 19

# %%
for i in tqdm_notebook(range(1, n_pages+1)):
    try:
        time.sleep(.2)
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        n_results = len(previous_results)
        results = yelp_api.search_query(location = location, term = term, 
                                    offset= n_results+1)
        previous_results.extend(results['businesses'])
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)
    except Exception as e:
        print (' [!] ERROR', e)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)
df.head()
# Out:
#                        id                                 alias  \
# 0  0IJgsg9ieOwSUtBOGF43XA  sakebomb-sushi-and-grill-sunnyvale-2
# 1  VbPU2itFPckFKv5bizLMAQ         fugetsu-sunnyvale-sunnyvale-2
# 2  j2rJ3W5c_CZ2tQh2QJ4oUA            sushi-tomi-mountain-view-2
# 3  4eTRqnAqFd2SDB0AvrMtQw           amami-shima-sushi-cupertino
# 4  hL8RzQIgXKh8SQ2P0KYx5Q               pacific-catch-sunnyvale
#
#                      name                                          image_url  \
# 0  Sakebomb Sushi & Grill  https://s3-media4.fl.yelpcdn.com/bphoto/qsVFSS...
# 1     Fugetsu - Sunnyvale  https://s3-media3.fl.yelpcdn.com/bphoto/C7fF6o...
# 2              Sushi Tomi  https://s3-media2.fl.yelpcdn.com/bphoto/WyWB3f...
# 3       Amami Shima Sushi  https://s3-media1.fl.yelpcdn.com/bphoto/pxcpMM...
# 4           Pacific Catch  https://s3-media1.fl.yelpcdn.com/bphoto/59W6VW...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/sakebomb-sushi-and-gr...           333
# 1      False  https://www.yelp.com/biz/fugetsu-sunnyvale-sun...           727
# 2      False  https://www.yelp.com/biz/sushi-tomi-mountain-v...          2496
# 3      False  https://www.yelp.com/biz/amami-shima-sushi-cup...          1101
# 4      False  https://www.yelp.com/biz/pacific-catch-sunnyva...           110
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 2  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 3  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 4  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 37.358093, 'longitude': -122.019296}          [delivery]
# 1  {'latitude': 37.376484715741775, 'longitude': ...            [pickup]
# 2  {'latitude': 37.3915303378286, 'longitude': -1...          [delivery]
# 3    {'latitude': 37.32265, 'longitude': -122.00596}  [pickup, delivery]
# 4  {'latitude': 37.374423, 'longitude': -122.033312}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '759 E El Camino Real', 'address2...  +14082124123
# 1    $$  {'address1': '190 S Frances St', 'address2': N...  +14087738225
# 2    $$  {'address1': '635 W Dana St', 'address2': '', ...
# 3    $$  {'address1': '19068 Stevens Creek Blvd', 'addr...  +14089968815
# 4    $$  {'address1': '300 W McKinley Ave', 'address2':...  +16696003858
#
#     display_phone     distance
# 0  (408) 212-4123  1823.017254
# 1  (408) 773-8225   665.693689
# 2                  5123.299043
# 3  (408) 996-8815  5944.946542
# 4  (669) 600-3858   782.653139

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             367 non-null    object
#  1   alias          367 non-null    object
#  2   name           367 non-null    object
#  3   image_url      367 non-null    object
#  4   is_closed      367 non-null    bool
#  5   url            367 non-null    object
#  6   review_count   367 non-null    int64
#  7   categories     367 non-null    object
#  8   rating         367 non-null    float64
#  9   coordinates    367 non-null    object
#  10  transactions   367 non-null    object
#  11  price          340 non-null    object
#  12  location       367 non-null    object
#  13  phone          367 non-null    object
#  14  display_phone  367 non-null    object
#  15  distance       367 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 43.5+ KB

# %%
csv_file = JSON_FILE.replace('.json', '.csv.gz')
csv_file
# Out:
# 'G:\\Github Desktop Reps\\Coding Dojo\\Yelp-API\\DataSunnyvale-sushi.csv.gz'

# %%
df.to_csv(csv_file, compression = 'gzip', index = False)
